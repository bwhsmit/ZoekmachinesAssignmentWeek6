# %%
from collections import Counter,defaultdict
from bs4 import BeautifulSoup
import os
import glob
import nltk
import math
from __future__ import division

# %% [markdown]
# ## Vragen uit Introduction IR
#
# *  Maak 12.3, 12.4, 12.6.a, 12.7-9

# %% [markdown]
# # 12.3

# %% [markdown]
# likelihood ratio: (0.2 x 0.1 x 0.01 x 0.01 x 0.03 x 0.02 x 0.04 x 0.005 x 0.003 x 0.001) / (0.15 x 0.12 x 0.0002 x 0.0001 x 0.03 x 0.04 x 0.04 x 0.01 x 0.015 x 0.002) $\approx$ 138.889

# %% [markdown]
# # 12.4

# %% [markdown]
# Having a STOP probability of 0.1 on for each model will not change the likelihood ratio, for it is the same on each side.

# %% [markdown]
# # 12.6.a

# %% [markdown]
# Under a MLE-estimated unigram probability model, what are P(the) and P(martian)?
#
# P(the) = 2/11
#
# P(martian) = 1/11

# %% [markdown]
# # 12.7

# %% [markdown]
# | Query       | Doc1 | Doc2 | Doc3 | Doc4 |
# |------       |------|------|------|------|
# | click       | 15/32 | 23/32 | 7/32 | 11/32 |
# | shears      | 1/8 | 1/16 | 1/16 | 3/16 |
# | click shears| 15/256 | 23/512 | 7/512 | 33/512 |
#
#
# Ranking for "click shears" : doc4, doc1, doc2, doc3

# %% [markdown]
# # 12.8

# %% [markdown]
# # 12.9
